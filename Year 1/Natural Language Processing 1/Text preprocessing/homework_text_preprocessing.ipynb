# %%
from google.colab import files, auth, drive

# %%
# Mount to drive
drive.mount('/content/gdrive', force_remount=True)
data_dir_drive ='/content/gdrive/My Drive/Colab Notebooks/NLP1/Tema2'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# # 1
# Choose a wikipedia article. You will download and acces the article using this python module: wikipedia. Use the content property to extract the text. Print the title of the article and the first N=200 words from the article (use the tokenizer).

# %%
! pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading https://files.pythonhosted.org/packages/67/35/25e68fbc99e672127cc6fbb14b8ec1ba3dfef035bf1e4c90f78f24a80b7d/wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (4.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wikipedia) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2019.11.28)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-cp36-none-any.whl size=11686 sha256=99c5c957c29cea1340a55e5471fd9ebf3eba5e9a21429fc663f3e54cbc348d65
#   Stored in directory: /root/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
! pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from nltk) (1.12.0)

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> wordnet
#     Downloading package wordnet to /root/nltk_data...
#       Unzipping corpora/wordnet.zip.
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
import wikipedia
from nltk.tokenize import sent_tokenize, word_tokenize

wikipedia.set_lang("en")
palde = wikipedia.page("George Emil Palade")
print(palde.title)
data = palde.content
words = word_tokenize(data)
words2 = [x for x in words if x.isalnum()]
print(words2[:200])
# Out:
# George Emil Palade
# ['George', 'Emil', 'Palade', 'ForMemRS', 'HonFRMS', 'Romanian', 'pronunciation', 'eˈmil', 'paˈlade', 'listen', 'November', '19', '1912', 'October', '7', '2008', 'was', 'a', 'cell', 'biologist', 'Described', 'as', 'the', 'most', 'influential', 'cell', 'biologist', 'ever', 'in', '1974', 'he', 'was', 'awarded', 'the', 'Nobel', 'Prize', 'in', 'Physiology', 'and', 'Medicine', 'along', 'with', 'Albert', 'Claude', 'and', 'Christian', 'de', 'Duve', 'The', 'prize', 'was', 'granted', 'for', 'his', 'innovations', 'in', 'electron', 'microscopy', 'and', 'cell', 'fractionation', 'which', 'together', 'laid', 'the', 'foundations', 'of', 'modern', 'molecular', 'cell', 'biology', 'the', 'most', 'notable', 'discovery', 'being', 'the', 'ribosomes', 'of', 'the', 'endoplasmic', 'reticulum', 'which', 'he', 'first', 'described', 'in', 'also', 'received', 'the', 'National', 'Medal', 'of', 'Science', 'in', 'Biological', 'Sciences', 'for', 'pioneering', 'discoveries', 'of', 'a', 'host', 'of', 'fundamental', 'highly', 'organized', 'structures', 'in', 'living', 'cells', 'in', '1986', 'and', 'was', 'previously', 'elected', 'a', 'Member', 'of', 'the', 'US', 'National', 'Academy', 'of', 'Science', 'in', '1961', 'In', '1968', 'he', 'elected', 'an', 'Honorary', 'Fellow', 'of', 'the', 'Royal', 'Microscopical', 'Society', 'HonFRMS', 'and', 'in', '1984', 'he', 'was', 'elected', 'a', 'Foreign', 'Member', 'of', 'the', 'Royal', 'Society', 'ForMemRS', 'Education', 'and', 'early', 'life', 'George', 'Emil', 'Palade', 'was', 'born', 'on', 'November', '19', '1912', 'in', 'Iași', 'Romania', 'his', 'father', 'was', 'a', 'professor', 'of', 'philosophy', 'at', 'the', 'University', 'of', 'Iași', 'and', 'his', 'mother', 'was', 'a', 'high', 'school', 'teacher', 'George', 'Palade', 'received', 'his', 'in', '1940', 'from', 'the', 'Carol']

# %% [markdown]
# # 2
# Expand language contractions (for example change "we're" in "we are") using pycontractions

# %%
! sudo apt install openjdk-8-jdk
! sudo update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
! pip install language-check
! pip install pycontractions
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# openjdk-8-jdk is already the newest version (8u242-b08-0ubuntu3~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.
# Requirement already satisfied: language-check in /usr/local/lib/python3.6/dist-packages (1.1)
# Requirement already satisfied: pycontractions in /usr/local/lib/python3.6/dist-packages (2.0.1)
# Requirement already satisfied: language-check>=1.0 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (1.1)
# Requirement already satisfied: gensim>=2.0 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (3.6.0)
# Requirement already satisfied: pyemd>=0.4.4 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (0.5.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.9.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.12.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.17.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.21.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.11.15)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.49.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (3.0.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.15 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.14.15)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.6.1)

# %%
! pip install pycontractions
# Out:
# Requirement already satisfied: pycontractions in /usr/local/lib/python3.6/dist-packages (2.0.1)
# Requirement already satisfied: gensim>=2.0 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (3.6.0)
# Requirement already satisfied: language-check>=1.0 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (1.1)
# Requirement already satisfied: pyemd>=0.4.4 in /usr/local/lib/python3.6/dist-packages (from pycontractions) (0.5.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.9.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.17.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim>=2.0->pycontractions) (1.4.1)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.11.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.21.0)
# Requirement already satisfied: boto>=2.32 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.49.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.9.4)
# Requirement already satisfied: botocore<1.15.0,>=1.14.15 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.14.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2019.11.28)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->smart-open>=1.2.1->gensim>=2.0->pycontractions) (2.6.1)

# %%
from pycontractions import Contractions

cont = Contractions(api_key="glove-twitter-100")

data2 = list(cont.expand_texts([data]))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
print(data2)
# Out:
# ['George Emil Palade ForMemRS HonFRMS (Romanian pronunciation: [ˈd͡ʒe̯ord͡ʒe eˈmil paˈlade] (listen); November 19, 1912 – October 7, 2008) was a Romanian-American cell biologist. Described as "the most influential cell biologist ever", in 1974 he was awarded the Nobel Prize in Physiology and Medicine along with Albert Claude and Christian de Duve. The prize was granted for his innovations in electron microscopy and cell fractionation which together laid the foundations of modern molecular cell biology, the most notable discovery being the ribosomes of the endoplasmic reticulum – which he first described in 1955.Palade also received the U.S. National Medal of Science in Biological Sciences for "pioneering discoveries of a host of fundamental, highly organized structures in living cells" in 1986, and was previously elected a Member of the US National Academy of Science in 1961. In 1968 he elected an Honorary Fellow of the Royal Microscopical Society (HonFRMS). and in 1984 he was elected a Foreign Member of the Royal Society (ForMemRS).\n\n\n== Education and early life ==\nGeorge Emil Palade was born on November 19, 1912 in Iași, Romania; his father was a professor of philosophy at the University of Iași and his mother was a high school teacher. George E. Palade received his M.D. in 1940 from the Carol Davila School of Medicine in Bucharest.\n\n\n== Career and research ==\nPalade was a member of the faculty at Carol Davila University until 1946, when he went to the United States to do postdoctoral research. While assisting Robert Chambers in the Biology Laboratory of New York University, he met Professor Albert Claude. He later joined Claude at the Rockefeller Institute for Medical Research.In 1952, Palade became a naturalized citizen of the United States. He worked at the Rockefeller Institute (1958–1973), and was a professor at Yale University Medical School (1973–1990), and University of California, San Diego (1990–2008). At UCSD, Palade was Professor of Medicine in Residence (Emeritus) in the Department of Cellular & Molecular Medicine, as well as a Dean for Scientific Affairs (Emeritus), in the School of Medicine at La Jolla, California.In 1970, he was awarded the Louisa Gross Horwitz Prize from Columbia University together with Renato Dulbecco winner of 1975 Nobel Prize in Physiology or Medicine "for discoveries concerning the functional organization of the cell that were seminal events in the development of modern cell biology", related to his previous research carried out at the Rockefeller Institute for Medical Research. His Nobel lecture, delivered on December 12, 1974, was entitled:  "Intracellular Aspects of the Process of Protein Secretion", published in 1992 by the Nobel Prize Foundation, He was elected an Honorary member of the Romanian Academy in 1975. In 1981, Palade became a founding member of the World Cultural Council. In 1988 he was also elected an Honorary Member of the American-Romanian Academy of Arts and Sciences (ARA).\nPalade was the first Chairman of the Department of Cell Biology at Yale University. Presently, the Chair of Cell Biology at Yale is named the "George Palade Professorship".\nAt the Rockefeller Institute for Medical Research, Palade used electron microscopy to study the internal organization of such cell structures as ribosomes, mitochondria, chloroplasts, the Golgi apparatus, and others. His most important discovery was made while using an experimental strategy known as a pulse-chase analysis. In the experiment Palade and his colleagues were able to confirm an existing hypothesis that a secretory pathway exists and that the Rough ER and the Golgi apparatus function together.\nHe focused on Weibel-Palade bodies (a storage organelle unique to the endothelium, containing von Willebrand factor and various proteins) which he described together with the Swiss anatomist Ewald R. Weibel.\n\n\n=== Palade\'s coworkers and approach in the 1960s ===\nThe following is a concise excerpt from Palade\'s  ...

# %% [markdown]
# # 3
# Create a list of all the words (in lower case), from the text, using the word tokenizer. We will name the list l_words. Remove the punctuation.

# %%
dataWithContractions = data2[0]
words = word_tokenize(dataWithContractions)

l_words = [x.lower() for x in words if x.isalnum()]
# l_words = set(l_words)

print(l_words)
# Out:
# ['george', 'emil', 'palade', 'formemrs', 'honfrms', 'romanian', 'pronunciation', 'eˈmil', 'paˈlade', 'listen', 'november', '19', '1912', 'october', '7', '2008', 'was', 'a', 'cell', 'biologist', 'described', 'as', 'the', 'most', 'influential', 'cell', 'biologist', 'ever', 'in', '1974', 'he', 'was', 'awarded', 'the', 'nobel', 'prize', 'in', 'physiology', 'and', 'medicine', 'along', 'with', 'albert', 'claude', 'and', 'christian', 'de', 'duve', 'the', 'prize', 'was', 'granted', 'for', 'his', 'innovations', 'in', 'electron', 'microscopy', 'and', 'cell', 'fractionation', 'which', 'together', 'laid', 'the', 'foundations', 'of', 'modern', 'molecular', 'cell', 'biology', 'the', 'most', 'notable', 'discovery', 'being', 'the', 'ribosomes', 'of', 'the', 'endoplasmic', 'reticulum', 'which', 'he', 'first', 'described', 'in', 'also', 'received', 'the', 'national', 'medal', 'of', 'science', 'in', 'biological', 'sciences', 'for', 'pioneering', 'discoveries', 'of', 'a', 'host', 'of', 'fundamental', 'highly', 'organized', 'structures', 'in', 'living', 'cells', 'in', '1986', 'and', 'was', 'previously', 'elected', 'a', 'member', 'of', 'the', 'us', 'national', 'academy', 'of', 'science', 'in', '1961', 'in', '1968', 'he', 'elected', 'an', 'honorary', 'fellow', 'of', 'the', 'royal', 'microscopical', 'society', 'honfrms', 'and', 'in', '1984', 'he', 'was', 'elected', 'a', 'foreign', 'member', 'of', 'the', 'royal', 'society', 'formemrs', 'education', 'and', 'early', 'life', 'george', 'emil', 'palade', 'was', 'born', 'on', 'november', '19', '1912', 'in', 'iași', 'romania', 'his', 'father', 'was', 'a', 'professor', 'of', 'philosophy', 'at', 'the', 'university', 'of', 'iași', 'and', 'his', 'mother', 'was', 'a', 'high', 'school', 'teacher', 'george', 'palade', 'received', 'his', 'in', '1940', 'from', 'the', 'carol', 'davila', 'school', 'of', 'medicine', 'in', 'bucharest', 'career', 'and', 'research', 'palade', 'was', 'a', 'member', 'of', 'the', 'faculty', 'at', 'carol', 'davila', 'university', 'until', '1946', 'when', 'he', 'went', 'to', 'the', 'united', 'states', 'to', 'do', 'postdoctoral', 'research', 'while', 'assisting', 'robert', 'chambers', 'in', 'the', 'biology', 'laboratory', 'of', 'new', 'york', 'university', 'he', 'met', 'professor', 'albert', 'claude', 'he', 'later', 'joined', 'claude', 'at', 'the', 'rockefeller', 'institute', 'for', 'medical', '1952', 'palade', 'became', 'a', 'naturalized', 'citizen', 'of', 'the', 'united', 'states', 'he', 'worked', 'at', 'the', 'rockefeller', 'institute', 'and', 'was', 'a', 'professor', 'at', 'yale', 'university', 'medical', 'school', 'and', 'university', 'of', 'california', 'san', 'diego', 'at', 'ucsd', 'palade', 'was', 'professor', 'of', 'medicine', 'in', 'residence', 'emeritus', 'in', 'the', 'department', 'of', 'cellular', 'molecular', 'medicine', 'as', 'well', 'as', 'a', 'dean', 'for', 'scientific', 'affairs', 'emeritus', 'in', 'the', 'school', 'of', 'medicine', 'at', 'la', 'jolla', '1970', 'he', 'was', 'awarded', 'the', 'louisa', 'gross', 'horwitz', 'prize', 'from', 'columbia', 'university', 'together', 'with', 'renato', 'dulbecco', 'winner', 'of', '1975', 'nobel', 'prize', 'in', 'physiology', 'or', 'medicine', 'for', 'discoveries', 'concerning', 'the', 'functional', 'organization', 'of', 'the', 'cell', 'that', 'were', 'seminal', 'events', 'in', 'the', 'development', 'of', 'modern', 'cell', 'biology', 'related', 'to', 'his', 'previous', 'research', 'carried', 'out', 'at', 'the', 'rockefeller', 'institute', 'for', 'medical', 'research', 'his', 'nobel', 'lecture', 'delivered', 'on', 'december', '12', '1974', 'was', 'entitled', 'intracellular', 'aspects', 'of', 'the', 'process', 'of', 'protein', 'secretion', 'published', 'in', '1992', 'by', 'the', 'nobel', 'prize', 'foundation', 'he', 'was', 'elected', 'an', 'honorary', 'member', 'of', 'the', 'romanian', 'academy', 'in', '1975', 'in', '1981', 'palade', 'became', 'a', 'founding', 'member', 'of', 'the', 'world', 'cultural', 'council', 'in', '1988', 'he', 'was', ...

# %% [markdown]
# # 4
# Remove stopwords from l_words and print the number of words in the text, before and after removing stopwords.

# %%
print(len(l_words))

from nltk.corpus import stopwords

stopwords = stopwords.words('english')

lws = [x for x in l_words if x not in stopwords]

print(len(lws))
# Out:
# 1108
# 730

# %% [markdown]
# # 5
# Using RegexpTokenizer (nltk) please obtain the list of words written with capital letter that don't appear in the beginning of the phrase (name this list lnm).

# %%
data
# Out:
# 'George Emil Palade ForMemRS HonFRMS (Romanian pronunciation: [ˈd͡ʒe̯ord͡ʒe eˈmil paˈlade] (listen); November 19, 1912 – October 7, 2008) was a Romanian-American cell biologist. Described as "the most influential cell biologist ever", in 1974 he was awarded the Nobel Prize in Physiology and Medicine along with Albert Claude and Christian de Duve. The prize was granted for his innovations in electron microscopy and cell fractionation which together laid the foundations of modern molecular cell biology, the most notable discovery being the ribosomes of the endoplasmic reticulum – which he first described in 1955.Palade also received the U.S. National Medal of Science in Biological Sciences for "pioneering discoveries of a host of fundamental, highly organized structures in living cells" in 1986, and was previously elected a Member of the US National Academy of Science in 1961. In 1968 he elected an Honorary Fellow of the Royal Microscopical Society (HonFRMS). and in 1984 he was elected a Foreign Member of the Royal Society (ForMemRS).\n\n\n== Education and early life ==\nGeorge Emil Palade was born on November 19, 1912 in Iași, Romania; his father was a professor of philosophy at the University of Iași and his mother was a high school teacher. George E. Palade received his M.D. in 1940 from the Carol Davila School of Medicine in Bucharest.\n\n\n== Career and research ==\nPalade was a member of the faculty at Carol Davila University until 1946, when he went to the United States to do postdoctoral research. While assisting Robert Chambers in the Biology Laboratory of New York University, he met Professor Albert Claude. He later joined Claude at the Rockefeller Institute for Medical Research.In 1952, Palade became a naturalized citizen of the United States. He worked at the Rockefeller Institute (1958–1973), and was a professor at Yale University Medical School (1973–1990), and University of California, San Diego (1990–2008). At UCSD, Palade was Professor of Medicine in Residence (Emeritus) in the Department of Cellular & Molecular Medicine, as well as a Dean for Scientific Affairs (Emeritus), in the School of Medicine at La Jolla, California.In 1970, he was awarded the Louisa Gross Horwitz Prize from Columbia University together with Renato Dulbecco winner of 1975 Nobel Prize in Physiology or Medicine "for discoveries concerning the functional organization of the cell that were seminal events in the development of modern cell biology", related to his previous research carried out at the Rockefeller Institute for Medical Research. His Nobel lecture, delivered on December 12, 1974, was entitled:  "Intracellular Aspects of the Process of Protein Secretion", published in 1992 by the Nobel Prize Foundation, He was elected an Honorary member of the Romanian Academy in 1975. In 1981, Palade became a founding member of the World Cultural Council. In 1988 he was also elected an Honorary Member of the American-Romanian Academy of Arts and Sciences (ARA).\nPalade was the first Chairman of the Department of Cell Biology at Yale University. Presently, the Chair of Cell Biology at Yale is named the "George Palade Professorship".\nAt the Rockefeller Institute for Medical Research, Palade used electron microscopy to study the internal organization of such cell structures as ribosomes, mitochondria, chloroplasts, the Golgi apparatus, and others. His most important discovery was made while using an experimental strategy known as a pulse-chase analysis. In the experiment Palade and his colleagues were able to confirm an existing hypothesis that a secretory pathway exists and that the Rough ER and the Golgi apparatus function together.\nHe focused on Weibel-Palade bodies (a storage organelle unique to the endothelium, containing von Willebrand factor and various proteins) which he described together with the Swiss anatomist Ewald R. Weibel.\n\n\n=== Palade\'s coworkers and approach in the 1960s ===\nThe following is a concise excerpt from Palade\'s A ...

# %%
from nltk.tokenize import RegexpTokenizer 
    
# Create a reference variable for Class RegexpTokenizer 
tk1 = RegexpTokenizer('[.?!][ ]+[A-Z]\w* ')
tk2 = RegexpTokenizer('[A-Z]\w*')
    
# Use tokenize method 
list1 = tk1.tokenize(data) 
list1 = [x[2:] for x in list1]
list2 = tk2.tokenize(data)[1:]

lnm = [item for item in list2 if item not in list1]
    
print(lnm)
# Out:
# ['Emil', 'Palade', 'ForMemRS', 'HonFRMS', 'Romanian', 'November', 'October', 'Romanian', 'American', 'Described', 'Nobel', 'Prize', 'Physiology', 'Medicine', 'Albert', 'Claude', 'Christian', 'Duve', 'The', 'Palade', 'U', 'S', 'National', 'Medal', 'Science', 'Biological', 'Sciences', 'Member', 'US', 'National', 'Academy', 'Science', 'In', 'Honorary', 'Fellow', 'Royal', 'Microscopical', 'Society', 'HonFRMS', 'Foreign', 'Member', 'Royal', 'Society', 'ForMemRS', 'Education', 'George', 'Emil', 'Palade', 'November', 'Iași', 'Romania', 'University', 'Iași', 'George', 'E', 'Palade', 'M', 'D', 'Carol', 'Davila', 'School', 'Medicine', 'Bucharest', 'Career', 'Palade', 'Carol', 'Davila', 'University', 'United', 'States', 'While', 'Robert', 'Chambers', 'Biology', 'Laboratory', 'New', 'York', 'University', 'Professor', 'Albert', 'Claude', 'He', 'Claude', 'Rockefeller', 'Institute', 'Medical', 'Research', 'In', 'Palade', 'United', 'States', 'He', 'Rockefeller', 'Institute', 'Yale', 'University', 'Medical', 'School', 'University', 'California', 'San', 'Diego', 'At', 'UCSD', 'Palade', 'Professor', 'Medicine', 'Residence', 'Emeritus', 'Department', 'Cellular', 'Molecular', 'Medicine', 'Dean', 'Scientific', 'Affairs', 'Emeritus', 'School', 'Medicine', 'La', 'Jolla', 'California', 'In', 'Louisa', 'Gross', 'Horwitz', 'Prize', 'Columbia', 'University', 'Renato', 'Dulbecco', 'Nobel', 'Prize', 'Physiology', 'Medicine', 'Rockefeller', 'Institute', 'Medical', 'Research', 'His', 'Nobel', 'December', 'Intracellular', 'Aspects', 'Process', 'Protein', 'Secretion', 'Nobel', 'Prize', 'Foundation', 'He', 'Honorary', 'Romanian', 'Academy', 'In', 'Palade', 'World', 'Cultural', 'Council', 'In', 'Honorary', 'Member', 'American', 'Romanian', 'Academy', 'Arts', 'Sciences', 'ARA', 'Palade', 'Chairman', 'Department', 'Cell', 'Biology', 'Yale', 'University', 'Presently', 'Chair', 'Cell', 'Biology', 'Yale', 'George', 'Palade', 'Professorship', 'At', 'Rockefeller', 'Institute', 'Medical', 'Research', 'Palade', 'Golgi', 'His', 'In', 'Palade', 'Rough', 'ER', 'Golgi', 'He', 'Weibel', 'Palade', 'Willebrand', 'Swiss', 'Ewald', 'R', 'Weibel', 'Palade', 'The', 'Palade', 'Autobiography', 'Nobel', 'Award', 'In', 'I', 'The', 'Philip', 'Siekevitz', 'Lewis', 'Joel', 'Greene', 'Colvin', 'Redman', 'David', 'Sabatini', 'Yutaka', 'Tashiro', 'The', 'Lucien', 'Caro', 'James', 'Jamieson', 'This', 'A', 'Nobel', 'Lecture', 'One', 'Nobel', 'Prize', 'Chemistry', 'Drs', 'Venkatraman', 'Ramakrishnan', 'Thomas', 'A', 'Steitz', 'Ada', 'E', 'Yonath', 'Dr', 'George', 'Emil', 'Palade', 'Personal', 'Palade', 'Marilyn', 'Farquhar', 'University', 'California', 'San', 'Diego', 'References', 'Bibliography', 'Singer', 'Manfred', 'V', 'Legacy', 'George', 'E', 'Palade', 'Pancreatology', 'ISSN', 'PMID', 'Haulică', 'I', 'Professor', 'George', 'Emil', 'Palade', 'Revista', 'Societăţii', 'Medici', 'Naturalişti', 'Iaşi', 'ISSN', 'PMID', 'Tartakoff', 'Alan', 'M', 'November', 'George', 'Emil', 'Palade', 'Nature', 'Reviews', 'Molecular', 'Cell', 'Biology', 'ISSN', 'PMID', 'Motta', 'P', 'M', 'George', 'Emil', 'Palade', 'Don', 'Wayne', 'Fawcett', 'Italian', 'Journal', 'Anatomy', 'Embryology', 'Suppl', 'XXI', 'XXXVIII', 'ISSN', 'PMID', 'Farquhar', 'M', 'G', 'Wissig', 'S', 'L', 'Palade', 'G', 'E', 'December', 'Glomerular', 'I', 'Ferritin', 'Journal', 'American', 'Society', 'Nephrology', 'ISSN', 'PMID', 'Raju', 'T', 'N', 'October', 'The', 'Nobel', 'Albert', 'Claude', 'George', 'Emil', 'Palade', 'Christian', 'Réne', 'Duve', 'The', 'Lancet', 'S0140', 'ISSN', 'PMID', 'Sabatini', 'D', 'D', 'October', 'George', 'E', 'Palade', 'Trends', 'Cell', 'Biology', 'S0962', 'ISSN', 'PMID', 'Motta', 'P', 'M', 'George', 'Emil', 'Palade', 'Don', 'Wayne', 'Fawcett', 'Italian', 'Journal', 'Anatomy', 'Embryology', 'ISSN', 'PMID', 'Porter', 'K', 'R', 'July', 'An', 'George', 'E', 'Palade', 'The', 'Journal', 'Cell', 'Biology', 'D3', 'ISSN', 'PMID', 'Tashiro', 'Y', 'January', 'Accomplishment', 'Drs', 'Albert', 'Calude', 'George', 'E', 'Palade', ' ...

# %% [markdown]
# # 6
# Remove all entity names (words that appear with capital letter inside the phrase, not at the beginning from l_words).

# %%
l_words = [item for item in l_words if item not in lnm]

print(l_words)
# Out:
# ['george', 'emil', 'palade', 'formemrs', 'honfrms', 'romanian', 'pronunciation', 'eˈmil', 'paˈlade', 'listen', 'november', '19', '1912', 'october', '7', '2008', 'was', 'a', 'cell', 'biologist', 'described', 'as', 'the', 'most', 'influential', 'cell', 'biologist', 'ever', 'in', '1974', 'he', 'was', 'awarded', 'the', 'nobel', 'prize', 'in', 'physiology', 'and', 'medicine', 'along', 'with', 'albert', 'claude', 'and', 'christian', 'de', 'duve', 'the', 'prize', 'was', 'granted', 'for', 'his', 'innovations', 'in', 'electron', 'microscopy', 'and', 'cell', 'fractionation', 'which', 'together', 'laid', 'the', 'foundations', 'of', 'modern', 'molecular', 'cell', 'biology', 'the', 'most', 'notable', 'discovery', 'being', 'the', 'ribosomes', 'of', 'the', 'endoplasmic', 'reticulum', 'which', 'he', 'first', 'described', 'in', 'also', 'received', 'the', 'national', 'medal', 'of', 'science', 'in', 'biological', 'sciences', 'for', 'pioneering', 'discoveries', 'of', 'a', 'host', 'of', 'fundamental', 'highly', 'organized', 'structures', 'in', 'living', 'cells', 'in', '1986', 'and', 'was', 'previously', 'elected', 'a', 'member', 'of', 'the', 'us', 'national', 'academy', 'of', 'science', 'in', '1961', 'in', '1968', 'he', 'elected', 'an', 'honorary', 'fellow', 'of', 'the', 'royal', 'microscopical', 'society', 'honfrms', 'and', 'in', '1984', 'he', 'was', 'elected', 'a', 'foreign', 'member', 'of', 'the', 'royal', 'society', 'formemrs', 'education', 'and', 'early', 'life', 'george', 'emil', 'palade', 'was', 'born', 'on', 'november', '19', '1912', 'in', 'iași', 'romania', 'his', 'father', 'was', 'a', 'professor', 'of', 'philosophy', 'at', 'the', 'university', 'of', 'iași', 'and', 'his', 'mother', 'was', 'a', 'high', 'school', 'teacher', 'george', 'palade', 'received', 'his', 'in', '1940', 'from', 'the', 'carol', 'davila', 'school', 'of', 'medicine', 'in', 'bucharest', 'career', 'and', 'research', 'palade', 'was', 'a', 'member', 'of', 'the', 'faculty', 'at', 'carol', 'davila', 'university', 'until', '1946', 'when', 'he', 'went', 'to', 'the', 'united', 'states', 'to', 'do', 'postdoctoral', 'research', 'while', 'assisting', 'robert', 'chambers', 'in', 'the', 'biology', 'laboratory', 'of', 'new', 'york', 'university', 'he', 'met', 'professor', 'albert', 'claude', 'he', 'later', 'joined', 'claude', 'at', 'the', 'rockefeller', 'institute', 'for', 'medical', '1952', 'palade', 'became', 'a', 'naturalized', 'citizen', 'of', 'the', 'united', 'states', 'he', 'worked', 'at', 'the', 'rockefeller', 'institute', 'and', 'was', 'a', 'professor', 'at', 'yale', 'university', 'medical', 'school', 'and', 'university', 'of', 'california', 'san', 'diego', 'at', 'ucsd', 'palade', 'was', 'professor', 'of', 'medicine', 'in', 'residence', 'emeritus', 'in', 'the', 'department', 'of', 'cellular', 'molecular', 'medicine', 'as', 'well', 'as', 'a', 'dean', 'for', 'scientific', 'affairs', 'emeritus', 'in', 'the', 'school', 'of', 'medicine', 'at', 'la', 'jolla', '1970', 'he', 'was', 'awarded', 'the', 'louisa', 'gross', 'horwitz', 'prize', 'from', 'columbia', 'university', 'together', 'with', 'renato', 'dulbecco', 'winner', 'of', '1975', 'nobel', 'prize', 'in', 'physiology', 'or', 'medicine', 'for', 'discoveries', 'concerning', 'the', 'functional', 'organization', 'of', 'the', 'cell', 'that', 'were', 'seminal', 'events', 'in', 'the', 'development', 'of', 'modern', 'cell', 'biology', 'related', 'to', 'his', 'previous', 'research', 'carried', 'out', 'at', 'the', 'rockefeller', 'institute', 'for', 'medical', 'research', 'his', 'nobel', 'lecture', 'delivered', 'on', 'december', '12', '1974', 'was', 'entitled', 'intracellular', 'aspects', 'of', 'the', 'process', 'of', 'protein', 'secretion', 'published', 'in', '1992', 'by', 'the', 'nobel', 'prize', 'foundation', 'he', 'was', 'elected', 'an', 'honorary', 'member', 'of', 'the', 'romanian', 'academy', 'in', '1975', 'in', '1981', 'palade', 'became', 'a', 'founding', 'member', 'of', 'the', 'world', 'cultural', 'council', 'in', '1988', 'he', 'was', ...

# %% [markdown]
# # 7
# Apply a stemmer (Snowball) on each of the word from the list of words, l_words (without changing the list) and print the result.

# %%
! pip install prettytable
# Out:
# Requirement already satisfied: prettytable in /usr/local/lib/python3.6/dist-packages (0.7.2)

# %%
import prettytable
t = prettytable.PrettyTable(["Word", "Snowball"])

snb=nltk.SnowballStemmer("english")

for x in l_words:
    snbW = snb.stem(x)
    t.add_row([x, snbW]) 
    
print(t)
# Out:
# +------------------+-----------------+
# |       Word       |     Snowball    |
# +------------------+-----------------+
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |     formemrs     |     formemr     |
# |     honfrms      |      honfrm     |
# |     romanian     |     romanian    |
# |  pronunciation   |     pronunci    |
# |      eˈmil       |      eˈmil      |
# |     paˈlade      |      paˈlad     |
# |      listen      |      listen     |
# |     november     |      novemb     |
# |        19        |        19       |
# |       1912       |       1912      |
# |     october      |      octob      |
# |        7         |        7        |
# |       2008       |       2008      |
# |       was        |       was       |
# |        a         |        a        |
# |       cell       |       cell      |
# |    biologist     |    biologist    |
# |    described     |     describ     |
# |        as        |        as       |
# |       the        |       the       |
# |       most       |       most      |
# |   influential    |    influenti    |
# |       cell       |       cell      |
# |    biologist     |    biologist    |
# |       ever       |       ever      |
# |        in        |        in       |
# |       1974       |       1974      |
# |        he        |        he       |
# |       was        |       was       |
# |     awarded      |      award      |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |      prize       |      prize      |
# |        in        |        in       |
# |    physiology    |    physiolog    |
# |       and        |       and       |
# |     medicine     |     medicin     |
# |      along       |      along      |
# |       with       |       with      |
# |      albert      |      albert     |
# |      claude      |      claud      |
# |       and        |       and       |
# |    christian     |    christian    |
# |        de        |        de       |
# |       duve       |       duve      |
# |       the        |       the       |
# |      prize       |      prize      |
# |       was        |       was       |
# |     granted      |      grant      |
# |       for        |       for       |
# |       his        |       his       |
# |   innovations    |      innov      |
# |        in        |        in       |
# |     electron     |     electron    |
# |    microscopy    |    microscopi   |
# |       and        |       and       |
# |       cell       |       cell      |
# |  fractionation   |     fraction    |
# |      which       |      which      |
# |     together     |      togeth     |
# |       laid       |       laid      |
# |       the        |       the       |
# |   foundations    |     foundat     |
# |        of        |        of       |
# |      modern      |      modern     |
# |    molecular     |    molecular    |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |       the        |       the       |
# |       most       |       most      |
# |     notable      |      notabl     |
# |    discovery     |    discoveri    |
# |      being       |        be       |
# |       the        |       the       |
# |    ribosomes     |     ribosom     |
# |        of        |        of       |
# |       the        |       the       |
# |   endoplasmic    |    endoplasm    |
# |    reticulum     |    reticulum    |
# |      which       |      which      |
# |        he        |        he       |
# |      first       |      first      |
# |    described     |     describ     |
# |        in        |        in       |
# |       also       |       also      |
# |     received     |      receiv     |
# |       the        |       the       |
# |     national     |      nation     |
# |      medal       |      medal      |
# |        of        |        of       |
# |     science      |      scienc     |
# |        in        |        in       |
# |    biological    |      biolog     |
# |     sciences     |      scienc     |
# |       for        |       for       |
# |    pioneering    |     pioneer     |
# |   discoveries    |    discoveri    |
# |        of        |        of       |
# |        a         |        a        |
# |       host       |       host      |
# |        of        |        of       |
# |   fundamental    |    fundament    |
# |      highly      |       high      |
# |    organized     |      organ      |
# |    structures    |     structur    |
# |        in        |        in       |
# |      living      |       live      |
# |      cells       |       cell      |
# |        in        |        in       |
# |       1986       |       1986      |
# |       and        |       and       |
# |       was        |       was       |
# |    previously    |     previous    |
# |     elected      |      elect      |
# |        a         |        a        |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |        us        |        us       |
# |     national     |      nation     |
# |     academy      |     academi     |
# |        of        |        of       |
# |     science      |      scienc     |
# |        in        |        in       |
# |       1961       |       1961      |
# |        in        |        in       |
# |       1968       |       1968      |
# |        he        |        he       |
# |     elected      |      elect      |
# |        an        |        an       |
# |     honorary     |     honorari    |
# |      fellow      |      fellow     |
# |        of        |        of       |
# |       the        |       the       |
# |      royal       |      royal      |
# |  microscopical   |    microscop    |
# |     society      |     societi     |
# |     honfrms      |      honfrm     |
# |       and        |       and       |
# |        in        |        in       |
# |       1984       |       1984      |
# |        he        |        he       |
# |       was        |       was       |
# |     elected      |      elect      |
# |        a         |        a        |
# |     foreign      |     foreign     |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |      royal       |      royal      |
# |     society      |     societi     |
# |     formemrs     |     formemr     |
# |    education     |       educ      |
# |       and        |       and       |
# |      early       |      earli      |
# |       life       |       life      |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |       was        |       was       |
# |       born       |       born      |
# |        on        |        on       |
# |     november     |      novemb     |
# |        19        |        19       |
# |       1912       |       1912      |
# |        in        |        in       |
# |       iași       |       iași      |
# |     romania      |     romania     |
# |       his        |       his       |
# |      father      |      father     |
# |       was        |       was       |
# |        a         |        a        |
# |    professor     |    professor    |
# |        of        |        of       |
# |    philosophy    |    philosophi   |
# |        at        |        at       |
# |       the        |       the       |
# |    university    |     univers     |
# |        of        |        of       |
# |       iași       |       iași      |
# |       and        |       and       |
# |       his        |       his       |
# |      mother      |      mother     |
# |       was        |       was       |
# |        a         |        a        |
# |       high       |       high      |
# |      school      |      school     |
# |     teacher      |     teacher     |
# |      george      |      georg      |
# |      palade      |      palad      |
# |     received     |      receiv     |
# |       his        |       his       |
# |        in        |        in       |
# |       1940       |       1940      |
# |       from       |       from      |
# |       the        |       the       |
# |      carol       |      carol      |
# |      davila      |      davila     |
# |      school      |      school     |
# |        of        |        of       |
# |     medicine     |     medicin     |
# |        in        |        in       |
# |    bucharest     |    bucharest    |
# |      career      |      career     |
# |       and        |       and       |
# |     research     |     research    |
# |      palade      |      palad      |
# |       was        |       was       |
# |        a         |        a        |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |     faculty      |     faculti     |
# |        at        |        at       |
# |      carol       |      carol      |
# |      davila      |      davila     |
# |    university    |     univers     |
# |      until       |      until      |
# |       1946       |       1946      |
# |       when       |       when      |
# |        he        |        he       |
# |       went       |       went      |
# |        to        |        to       |
# |       the        |       the       |
# |      united      |       unit      |
# |      states      |      state      |
# |        to        |        to       |
# |        do        |        do       |
# |   postdoctoral   |    postdoctor   |
# |     research     |     research    |
# |      while       |      while      |
# |    assisting     |      assist     |
# |      robert      |      robert     |
# |     chambers     |     chamber     |
# |        in        |        in       |
# |       the        |       the       |
# |     biology      |      biolog     |
# |    laboratory    |    laboratori   |
# |        of        |        of       |
# |       new        |       new       |
# |       york       |       york      |
# |    university    |     univers     |
# |        he        |        he       |
# |       met        |       met       |
# |    professor     |    professor    |
# |      albert      |      albert     |
# |      claude      |      claud      |
# |        he        |        he       |
# |      later       |      later      |
# |      joined      |       join      |
# |      claude      |      claud      |
# |        at        |        at       |
# |       the        |       the       |
# |   rockefeller    |     rockefel    |
# |    institute     |     institut    |
# |       for        |       for       |
# |     medical      |      medic      |
# |       1952       |       1952      |
# |      palade      |      palad      |
# |      became      |      becam      |
# |        a         |        a        |
# |   naturalized    |      natur      |
# |     citizen      |     citizen     |
# |        of        |        of       |
# |       the        |       the       |
# |      united      |       unit      |
# |      states      |      state      |
# |        he        |        he       |
# |      worked      |       work      |
# |        at        |        at       |
# |       the        |       the       |
# |   rockefeller    |     rockefel    |
# |    institute     |     institut    |
# |       and        |       and       |
# |       was        |       was       |
# |        a         |        a        |
# |    professor     |    professor    |
# |        at        |        at       |
# |       yale       |       yale      |
# |    university    |     univers     |
# |     medical      |      medic      |
# |      school      |      school     |
# |       and        |       and       |
# |    university    |     univers     |
# |        of        |        of       |
# |    california    |    california   |
# |       san        |       san       |
# |      diego       |      diego      |
# |        at        |        at       |
# |       ucsd       |       ucsd      |
# |      palade      |      palad      |
# |       was        |       was       |
# |    professor     |    professor    |
# |        of        |        of       |
# |     medicine     |     medicin     |
# |        in        |        in       |
# |    residence     |      resid      |
# |     emeritus     |     emeritus    |
# |        in        |        in       |
# |       the        |       the       |
# |    department    |      depart     |
# |        of        |        of       |
# |     cellular     |     cellular    |
# |    molecular     |    molecular    |
# |     medicine     |     medicin     |
# |        as        |        as       |
# |       well       |       well      |
# |        as        |        as       |
# |        a         |        a        |
# |       dean       |       dean      |
# |       for        |       for       |
# |    scientific    |     scientif    |
# |     affairs      |      affair     |
# |     emeritus     |     emeritus    |
# |        in        |        in       |
# |       the        |       the       |
# |      school      |      school     |
# |        of        |        of       |
# |     medicine     |     medicin     |
# |        at        |        at       |
# |        la        |        la       |
# |      jolla       |      jolla      |
# |       1970       |       1970      |
# |        he        |        he       |
# |       was        |       was       |
# |     awarded      |      award      |
# |       the        |       the       |
# |      louisa      |      louisa     |
# |      gross       |      gross      |
# |     horwitz      |     horwitz     |
# |      prize       |      prize      |
# |       from       |       from      |
# |     columbia     |     columbia    |
# |    university    |     univers     |
# |     together     |      togeth     |
# |       with       |       with      |
# |      renato      |      renato     |
# |     dulbecco     |     dulbecco    |
# |      winner      |      winner     |
# |        of        |        of       |
# |       1975       |       1975      |
# |      nobel       |      nobel      |
# |      prize       |      prize      |
# |        in        |        in       |
# |    physiology    |    physiolog    |
# |        or        |        or       |
# |     medicine     |     medicin     |
# |       for        |       for       |
# |   discoveries    |    discoveri    |
# |    concerning    |     concern     |
# |       the        |       the       |
# |    functional    |     function    |
# |   organization   |      organ      |
# |        of        |        of       |
# |       the        |       the       |
# |       cell       |       cell      |
# |       that       |       that      |
# |       were       |       were      |
# |     seminal      |      semin      |
# |      events      |      event      |
# |        in        |        in       |
# |       the        |       the       |
# |   development    |     develop     |
# |        of        |        of       |
# |      modern      |      modern     |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |     related      |      relat      |
# |        to        |        to       |
# |       his        |       his       |
# |     previous     |     previous    |
# |     research     |     research    |
# |     carried      |      carri      |
# |       out        |       out       |
# |        at        |        at       |
# |       the        |       the       |
# |   rockefeller    |     rockefel    |
# |    institute     |     institut    |
# |       for        |       for       |
# |     medical      |      medic      |
# |     research     |     research    |
# |       his        |       his       |
# |      nobel       |      nobel      |
# |     lecture      |      lectur     |
# |    delivered     |      deliv      |
# |        on        |        on       |
# |     december     |      decemb     |
# |        12        |        12       |
# |       1974       |       1974      |
# |       was        |       was       |
# |     entitled     |      entitl     |
# |  intracellular   |  intracellular  |
# |     aspects      |      aspect     |
# |        of        |        of       |
# |       the        |       the       |
# |     process      |     process     |
# |        of        |        of       |
# |     protein      |     protein     |
# |    secretion     |      secret     |
# |    published     |     publish     |
# |        in        |        in       |
# |       1992       |       1992      |
# |        by        |        by       |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |      prize       |      prize      |
# |    foundation    |     foundat     |
# |        he        |        he       |
# |       was        |       was       |
# |     elected      |      elect      |
# |        an        |        an       |
# |     honorary     |     honorari    |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |     romanian     |     romanian    |
# |     academy      |     academi     |
# |        in        |        in       |
# |       1975       |       1975      |
# |        in        |        in       |
# |       1981       |       1981      |
# |      palade      |      palad      |
# |      became      |      becam      |
# |        a         |        a        |
# |     founding     |      found      |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |      world       |      world      |
# |     cultural     |      cultur     |
# |     council      |     council     |
# |        in        |        in       |
# |       1988       |       1988      |
# |        he        |        he       |
# |       was        |       was       |
# |       also       |       also      |
# |     elected      |      elect      |
# |        an        |        an       |
# |     honorary     |     honorari    |
# |      member      |      member     |
# |        of        |        of       |
# |       the        |       the       |
# |     academy      |     academi     |
# |        of        |        of       |
# |       arts       |       art       |
# |       and        |       and       |
# |     sciences     |      scienc     |
# |       ara        |       ara       |
# |      palade      |      palad      |
# |       was        |       was       |
# |       the        |       the       |
# |      first       |      first      |
# |     chairman     |     chairman    |
# |        of        |        of       |
# |       the        |       the       |
# |    department    |      depart     |
# |        of        |        of       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |        at        |        at       |
# |       yale       |       yale      |
# |    university    |     univers     |
# |    presently     |     present     |
# |       the        |       the       |
# |      chair       |      chair      |
# |        of        |        of       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |        at        |        at       |
# |       yale       |       yale      |
# |        is        |        is       |
# |      named       |       name      |
# |       the        |       the       |
# |      george      |      georg      |
# |      palade      |      palad      |
# |  professorship   |  professorship  |
# |        at        |        at       |
# |       the        |       the       |
# |   rockefeller    |     rockefel    |
# |    institute     |     institut    |
# |       for        |       for       |
# |     medical      |      medic      |
# |     research     |     research    |
# |      palade      |      palad      |
# |       used       |       use       |
# |     electron     |     electron    |
# |    microscopy    |    microscopi   |
# |        to        |        to       |
# |      study       |      studi      |
# |       the        |       the       |
# |     internal     |      intern     |
# |   organization   |      organ      |
# |        of        |        of       |
# |       such       |       such      |
# |       cell       |       cell      |
# |    structures    |     structur    |
# |        as        |        as       |
# |    ribosomes     |     ribosom     |
# |   mitochondria   |   mitochondria  |
# |   chloroplasts   |   chloroplast   |
# |       the        |       the       |
# |      golgi       |      golgi      |
# |    apparatus     |    apparatus    |
# |       and        |       and       |
# |      others      |      other      |
# |       his        |       his       |
# |       most       |       most      |
# |    important     |      import     |
# |    discovery     |    discoveri    |
# |       was        |       was       |
# |       made       |       made      |
# |      while       |      while      |
# |      using       |       use       |
# |        an        |        an       |
# |   experimental   |    experiment   |
# |     strategy     |     strategi    |
# |      known       |      known      |
# |        as        |        as       |
# |        a         |        a        |
# |     analysis     |     analysi     |
# |        in        |        in       |
# |       the        |       the       |
# |    experiment    |      experi     |
# |      palade      |      palad      |
# |       and        |       and       |
# |       his        |       his       |
# |    colleagues    |     colleagu    |
# |       were       |       were      |
# |       able       |       abl       |
# |        to        |        to       |
# |     confirm      |     confirm     |
# |        an        |        an       |
# |     existing     |      exist      |
# |    hypothesis    |    hypothesi    |
# |       that       |       that      |
# |        a         |        a        |
# |    secretory     |    secretori    |
# |     pathway      |     pathway     |
# |      exists      |      exist      |
# |       and        |       and       |
# |       that       |       that      |
# |       the        |       the       |
# |      rough       |      rough      |
# |        er        |        er       |
# |       and        |       and       |
# |       the        |       the       |
# |      golgi       |      golgi      |
# |    apparatus     |    apparatus    |
# |     function     |     function    |
# |     together     |      togeth     |
# |        he        |        he       |
# |     focused      |      focus      |
# |        on        |        on       |
# |      bodies      |       bodi      |
# |        a         |        a        |
# |     storage      |      storag     |
# |    organelle     |     organell    |
# |      unique      |      uniqu      |
# |        to        |        to       |
# |       the        |       the       |
# |   endothelium    |   endothelium   |
# |    containing    |     contain     |
# |       von        |       von       |
# |    willebrand    |    willebrand   |
# |      factor      |      factor     |
# |       and        |       and       |
# |     various      |     various     |
# |     proteins     |     protein     |
# |      which       |      which      |
# |        he        |        he       |
# |    described     |     describ     |
# |     together     |      togeth     |
# |       with       |       with      |
# |       the        |       the       |
# |      swiss       |      swiss      |
# |    anatomist     |    anatomist    |
# |      ewald       |      ewald      |
# |      weibel      |      weibel     |
# |      palade      |      palad      |
# |    coworkers     |      cowork     |
# |       and        |       and       |
# |     approach     |     approach    |
# |        in        |        in       |
# |       the        |       the       |
# |      1960s       |      1960s      |
# |       the        |       the       |
# |    following     |      follow     |
# |        is        |        is       |
# |        a         |        a        |
# |     concise      |      concis     |
# |     excerpt      |     excerpt     |
# |       from       |       from      |
# |      palade      |      palad      |
# |  autobiography   |  autobiographi  |
# |    appearing     |      appear     |
# |        in        |        in       |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |      award       |      award      |
# |    documents     |     document    |
# |        in        |        in       |
# |       the        |       the       |
# |      1960s       |      1960s      |
# |        i         |        i        |
# |    continued     |     continu     |
# |       the        |       the       |
# |       work       |       work      |
# |        on        |        on       |
# |       the        |       the       |
# |    secretory     |    secretori    |
# |     process      |     process     |
# |      using       |       use       |
# |        in        |        in       |
# |     parallel     |     parallel    |
# |        or        |        or       |
# |        in        |        in       |
# |    succession    |     success     |
# |       two        |       two       |
# |    different     |      differ     |
# |    approaches    |     approach    |
# |       the        |       the       |
# |      first       |      first      |
# |      relied      |       reli      |
# |   exclusively    |      exclus     |
# |        on        |        on       |
# |       cell       |       cell      |
# |  fractionation   |     fraction    |
# |       and        |       and       |
# |       was        |       was       |
# |    developed     |     develop     |
# |        in        |        in       |
# |  collaboration   |     collabor    |
# |       with       |       with      |
# |      philip      |      philip     |
# |    siekevitz     |    siekevitz    |
# |      lewis       |       lewi      |
# |       joel       |       joel      |
# |      greene      |      green      |
# |      colvin      |      colvin     |
# |      redman      |      redman     |
# |      david       |      david      |
# |     sabatini     |     sabatini    |
# |       and        |       and       |
# |      yutaka      |      yutaka     |
# |     tashiro      |     tashiro     |
# |        it        |        it       |
# |       led        |       led       |
# |        to        |        to       |
# |       the        |       the       |
# | characterization |    character    |
# |        of        |        of       |
# |       the        |       the       |
# |     zymogen      |     zymogen     |
# |     granules     |      granul     |
# |       and        |       and       |
# |        to        |        to       |
# |       the        |       the       |
# |    discovery     |    discoveri    |
# |        of        |        of       |
# |       the        |       the       |
# |   segregation    |      segreg     |
# |        of        |        of       |
# |    secretory     |    secretori    |
# |     products     |     product     |
# |        in        |        in       |
# |       the        |       the       |
# |    cisternal     |     cistern     |
# |      space       |      space      |
# |        of        |        of       |
# |       the        |       the       |
# |   endoplasmic    |    endoplasm    |
# |    reticulum     |    reticulum    |
# |       the        |       the       |
# |      second      |      second     |
# |     approach     |     approach    |
# |      relied      |       reli      |
# |    primarily     |    primarili    |
# |        on        |        on       |
# | radioautography  | radioautographi |
# |       and        |       and       |
# |     involved     |      involv     |
# |   experiments    |      experi     |
# |        on        |        on       |
# |      intact      |      intact     |
# |     animals      |       anim      |
# |        or        |        or       |
# |    pancreatic    |     pancreat    |
# |      slices      |      slice      |
# |      which       |      which      |
# |       were       |       were      |
# |     carried      |      carri      |
# |       out        |       out       |
# |        in        |        in       |
# |  collaboration   |     collabor    |
# |       with       |       with      |
# |      lucien      |      lucien     |
# |       caro       |       caro      |
# |       and        |       and       |
# |    especially    |      especi     |
# |      james       |       jame      |
# |     jamieson     |     jamieson    |
# |       this       |       this      |
# |      series      |       seri      |
# |        of        |        of       |
# |  investigations  |     investig    |
# |     produced     |      produc     |
# |        a         |        a        |
# |       good       |       good      |
# |       part       |       part      |
# |        of        |        of       |
# |       our        |       our       |
# |     current      |     current     |
# |      ideas       |       idea      |
# |        on        |        on       |
# |       the        |       the       |
# |    synthesis     |     synthesi    |
# |       and        |       and       |
# |  intracellular   |  intracellular  |
# |    processing    |     process     |
# |        of        |        of       |
# |     proteins     |     protein     |
# |       for        |       for       |
# |      export      |      export     |
# |        a         |        a        |
# |     critical     |      critic     |
# |      review      |      review     |
# |        of        |        of       |
# |       this       |       this      |
# |       line       |       line      |
# |        of        |        of       |
# |     research     |     research    |
# |        is        |        is       |
# |    presented     |     present     |
# |        in        |        in       |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |     lecture      |      lectur     |
# |       one        |       one       |
# |      notes       |       note      |
# |       also       |       also      |
# |       that       |       that      |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |      prize       |      prize      |
# |        in        |        in       |
# |    chemistry     |    chemistri    |
# |       was        |       was       |
# |     awarded      |      award      |
# |        in        |        in       |
# |       2009       |       2009      |
# |        to        |        to       |
# |       drs        |       drs       |
# |   venkatraman    |   venkatraman   |
# |   ramakrishnan   |   ramakrishnan  |
# |      thomas      |      thoma      |
# |      steitz      |      steitz     |
# |       and        |       and       |
# |       ada        |       ada       |
# |      yonath      |      yonath     |
# |       for        |       for       |
# |     studies      |      studi      |
# |        of        |        of       |
# |       the        |       the       |
# |    structure     |     structur    |
# |       and        |       and       |
# |     function     |     function    |
# |        of        |        of       |
# |       the        |       the       |
# |     ribosome     |     ribosom     |
# |    discovered    |      discov     |
# |        by        |        by       |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |     personal     |      person     |
# |       life       |       life      |
# |      palade      |      palad      |
# |        is        |        is       |
# |     survived     |      surviv     |
# |        by        |        by       |
# |       his        |       his       |
# |       wife       |       wife      |
# |     marilyn      |     marilyn     |
# |     farquhar     |     farquhar    |
# |        a         |        a        |
# |       cell       |       cell      |
# |    biologist     |    biologist    |
# |        at        |        at       |
# |       the        |       the       |
# |    university    |     univers     |
# |        of        |        of       |
# |    california    |    california   |
# |       san        |       san       |
# |      diego       |      diego      |
# |       and        |       and       |
# |        a         |        a        |
# |     daughter     |     daughter    |
# |       and        |       and       |
# |       son        |       son       |
# |       from       |       from      |
# |       his        |       his       |
# |      first       |      first      |
# |     marriage     |     marriag     |
# |    references    |      refer      |
# |   bibliography   |   bibliographi  |
# |      singer      |      singer     |
# |     manfred      |      manfr      |
# |        v         |        v        |
# |       2003       |       2003      |
# |      legacy      |      legaci     |
# |        of        |        of       |
# |        a         |        a        |
# |  distinguished   |   distinguish   |
# |    scientist     |    scientist    |
# |      george      |      georg      |
# |      palade      |      palad      |
# |  pancreatology   |   pancreatolog  |
# |        3         |        3        |
# |        6         |        6        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |        i         |        i        |
# |       2002       |       2002      |
# |    professor     |    professor    |
# |      doctor      |      doctor     |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |        at        |        at       |
# |        90        |        90       |
# |      years       |       year      |
# |        of        |        of       |
# |       age        |       age       |
# |     revista      |     revista     |
# |        a         |        a        |
# |    societăţii    |    societăţii   |
# |        de        |        de       |
# |      medici      |      medici     |
# |        şi        |        şi       |
# |   naturalişti    |   naturalişti   |
# |       din        |       din       |
# |       iaşi       |       iaşi      |
# |       107        |       107       |
# |        2         |        2        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     12638263     |     12638263    |
# |    tartakoff     |    tartakoff    |
# |       alan       |       alan      |
# |        m         |        m        |
# |     november     |      novemb     |
# |       2002       |       2002      |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |   charismatic    |    charismat    |
# |     virtuoso     |     virtuoso    |
# |        of        |        of       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |      nature      |      natur      |
# |     reviews      |      review     |
# |    molecular     |    molecular    |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |        3         |        3        |
# |        11        |        11       |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     12415304     |     12415304    |
# |      motta       |      motta      |
# |        p         |        p        |
# |        m         |        m        |
# |       2001       |       2001      |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |       and        |       and       |
# |       don        |       don       |
# |      wayne       |       wayn      |
# |     fawcett      |     fawcett     |
# |       and        |       and       |
# |       the        |       the       |
# |   development    |     develop     |
# |        of        |        of       |
# |      modern      |      modern     |
# |     anatomy      |     anatomi     |
# |    histology     |     histolog    |
# |       and        |       and       |
# |   contemporary   |   contemporari  |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |     italian      |     italian     |
# |     journal      |     journal     |
# |        of        |        of       |
# |     anatomy      |     anatomi     |
# |       and        |       and       |
# |    embryology    |    embryolog    |
# |       106        |       106       |
# |        2         |        2        |
# |      suppl       |      suppl      |
# |        1         |        1        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     11730003     |     11730003    |
# |     farquhar     |     farquhar    |
# |        m         |        m        |
# |        g         |        g        |
# |      wissig      |      wissig     |
# |        s         |        s        |
# |        l         |        l        |
# |      palade      |      palad      |
# |        g         |        g        |
# |        e         |        e        |
# |     december     |      decemb     |
# |       1999       |       1999      |
# |    glomerular    |    glomerular   |
# |   permeability   |     permeabl    |
# |     ferritin     |     ferritin    |
# |     transfer     |     transfer    |
# |      across      |      across     |
# |       the        |       the       |
# |      normal      |      normal     |
# |    glomerular    |    glomerular   |
# |    capillary     |    capillari    |
# |       wall       |       wall      |
# |       1961       |       1961      |
# |     journal      |     journal     |
# |        of        |        of       |
# |       the        |       the       |
# |     american     |     american    |
# |     society      |     societi     |
# |        of        |        of       |
# |    nephrology    |    nephrolog    |
# |        10        |        10       |
# |        12        |        12       |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     10589706     |     10589706    |
# |       raju       |       raju      |
# |        t         |        t        |
# |        n         |        n        |
# |     october      |      octob      |
# |       1999       |       1999      |
# |       the        |       the       |
# |      nobel       |      nobel      |
# |    chronicles    |     chronicl    |
# |       1974       |       1974      |
# |      albert      |      albert     |
# |      claude      |      claud      |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |        b         |        b        |
# |       1912       |       1912      |
# |       and        |       and       |
# |    christian     |    christian    |
# |       réne       |       réne      |
# |        de        |        de       |
# |       duve       |       duve      |
# |        b         |        b        |
# |       1917       |       1917      |
# |       the        |       the       |
# |      lancet      |      lancet     |
# |       354        |       354       |
# |       9185       |       9185      |
# |        05        |        05       |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     10513750     |     10513750    |
# |     sabatini     |     sabatini    |
# |        d         |        d        |
# |        d         |        d        |
# |     october      |      octob      |
# |       1999       |       1999      |
# |      george      |      georg      |
# |      palade      |      palad      |
# |     charting     |      chart      |
# |       the        |       the       |
# |    secretory     |    secretori    |
# |     pathway      |     pathway     |
# |      trends      |      trend      |
# |        in        |        in       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |        9         |        9        |
# |        10        |        10       |
# |        99        |        99       |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     10481180     |     10481180    |
# |      motta       |      motta      |
# |        p         |        p        |
# |        m         |        m        |
# |       1998       |       1998      |
# |      george      |      georg      |
# |       emil       |       emil      |
# |      palade      |      palad      |
# |       and        |       and       |
# |       don        |       don       |
# |      wayne       |       wayn      |
# |     fawcett      |     fawcett     |
# |       and        |       and       |
# |       the        |       the       |
# |   development    |     develop     |
# |        of        |        of       |
# |      modern      |      modern     |
# |     anatomy      |     anatomi     |
# |    histology     |     histolog    |
# |       and        |       and       |
# |   contemporary   |   contemporari  |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |     italian      |     italian     |
# |     journal      |     journal     |
# |        of        |        of       |
# |     anatomy      |     anatomi     |
# |       and        |       and       |
# |    embryology    |    embryolog    |
# |       103        |       103       |
# |        2         |        2        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     9719773      |     9719773     |
# |      porter      |      porter     |
# |        k         |        k        |
# |        r         |        r        |
# |       july       |       juli      |
# |       1983       |       1983      |
# |        an        |        an       |
# |     informal     |      inform     |
# |     tribute      |      tribut     |
# |        to        |        to       |
# |      george      |      georg      |
# |      palade      |      palad      |
# |       the        |       the       |
# |     journal      |     journal     |
# |        of        |        of       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |        97        |        97       |
# |        1         |        1        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     6345553      |     6345553     |
# |     tashiro      |     tashiro     |
# |        y         |        y        |
# |     january      |     januari     |
# |       1975       |       1975      |
# |  accomplishment  |    accomplish   |
# |        of        |        of       |
# |       drs        |       drs       |
# |      albert      |      albert     |
# |      calude      |      calud      |
# |       and        |       and       |
# |      george      |      georg      |
# |      palade      |      palad      |
# |       and        |       and       |
# |       the        |       the       |
# |      birth       |      birth      |
# |        of        |        of       |
# |       cell       |       cell      |
# |     biology      |      biolog     |
# |  tanpakushitsu   |  tanpakushitsu  |
# |     kakusan      |     kakusan     |
# |       koso       |       koso      |
# |        20        |        20       |
# |        1         |        1        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     1094498      |     1094498     |
# |      magner      |      magner     |
# |        j         |        j        |
# |        w         |        w        |
# |     ritchie      |      ritchi     |
# |        e         |        e        |
# |        h         |        h        |
# |      cahill      |      cahil      |
# |        s         |        s        |
# |        c         |        c        |
# |     january      |     januari     |
# |       1975       |       1975      |
# |     current      |     current     |
# |     medical      |      medic      |
# |    literature    |    literatur    |
# |     journal      |     journal     |
# |        of        |        of       |
# |       the        |       the       |
# |      indian      |      indian     |
# |     medical      |      medic      |
# |   association    |      associ     |
# |        64        |        64       |
# |        1         |        1        |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     1094070      |     1094070     |
# |      george      |      georg      |
# |      palade      |      palad      |
# |     triangle     |     triangl     |
# |        9         |        9        |
# |        6         |        6        |
# |       1970       |       1970      |
# |       issn       |       issn      |
# |       pmid       |       pmid      |
# |     4927031      |     4927031     |
# +------------------+-----------------+

# %% [markdown]
# # 8
# Apply a lematizer on each of the word from the list of words, l_words (without changing the list) and print the result. Explain the different result (from the stemming process) in a comment.

# %%
from nltk.stem import WordNetLemmatizer

t = prettytable.PrettyTable(["Word", "Snowball", "WordNetLemmatizer"])

snb=nltk.SnowballStemmer("english")
lem=WordNetLemmatizer()

for x in lws:
    snbW = snb.stem(x)
    lemW = lem.lemmatize(x, pos="v")

    if lemW != snbW:
        t.add_row([x, snbW, lemW]) 
print(t)

# The differences between stemming and lemmatizer processes are that: 
# in stemming, the root of a word is returned and in lemmatizer the 
# canonical form of the word is returned (as it appears in the dictionary)
# Out:
# +------------------+-----------------+-------------------+
# |       Word       |     Snowball    | WordNetLemmatizer |
# +------------------+-----------------+-------------------+
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     formemrs     |     formemr     |      formemrs     |
# |     honfrms      |      honfrm     |      honfrms      |
# |  pronunciation   |     pronunci    |   pronunciation   |
# |     paˈlade      |      paˈlad     |      paˈlade      |
# |     november     |      novemb     |      november     |
# |     october      |      octob      |      october      |
# |    described     |     describ     |      describe     |
# |   influential    |    influenti    |    influential    |
# |    physiology    |    physiolog    |     physiology    |
# |     medicine     |     medicin     |      medicine     |
# |      claude      |      claud      |       claude      |
# |   innovations    |      innov      |    innovations    |
# |    microscopy    |    microscopi   |     microscopy    |
# |  fractionation   |     fraction    |   fractionation   |
# |     together     |      togeth     |      together     |
# |       laid       |       laid      |        lay        |
# |   foundations    |     foundat     |    foundations    |
# |     biology      |      biolog     |      biology      |
# |     notable      |      notabl     |      notable      |
# |    discovery     |    discoveri    |     discovery     |
# |    ribosomes     |     ribosom     |     ribosomes     |
# |   endoplasmic    |    endoplasm    |    endoplasmic    |
# |    described     |     describ     |      describe     |
# |     received     |      receiv     |      receive      |
# |     national     |      nation     |      national     |
# |     science      |      scienc     |      science      |
# |    biological    |      biolog     |     biological    |
# |     sciences     |      scienc     |      sciences     |
# |   discoveries    |    discoveri    |    discoveries    |
# |   fundamental    |    fundament    |    fundamental    |
# |      highly      |       high      |       highly      |
# |    organized     |      organ      |      organize     |
# |    structures    |     structur    |     structure     |
# |      cells       |       cell      |       cells       |
# |    previously    |     previous    |     previously    |
# |     national     |      nation     |      national     |
# |     academy      |     academi     |      academy      |
# |     science      |      scienc     |      science      |
# |     honorary     |     honorari    |      honorary     |
# |  microscopical   |    microscop    |   microscopical   |
# |     society      |     societi     |      society      |
# |     honfrms      |      honfrm     |      honfrms      |
# |     society      |     societi     |      society      |
# |     formemrs     |     formemr     |      formemrs     |
# |    education     |       educ      |     education     |
# |      early       |      earli      |       early       |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |       born       |       born      |        bear       |
# |     november     |      novemb     |      november     |
# |    philosophy    |    philosophi   |     philosophy    |
# |    university    |     univers     |     university    |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     received     |      receiv     |      receive      |
# |     medicine     |     medicin     |      medicine     |
# |      palade      |      palad      |       palade      |
# |     faculty      |     faculti     |      faculty      |
# |    university    |     univers     |     university    |
# |       went       |       went      |         go        |
# |      united      |       unit      |       unite       |
# |   postdoctoral   |    postdoctor   |    postdoctoral   |
# |     biology      |      biolog     |      biology      |
# |    laboratory    |    laboratori   |     laboratory    |
# |    university    |     univers     |     university    |
# |       met        |       met       |        meet       |
# |      claude      |      claud      |       claude      |
# |      claude      |      claud      |       claude      |
# |   rockefeller    |     rockefel    |    rockefeller    |
# |    institute     |     institut    |     institute     |
# |     medical      |      medic      |      medical      |
# |      palade      |      palad      |       palade      |
# |      became      |      becam      |       become      |
# |   naturalized    |      natur      |     naturalize    |
# |      united      |       unit      |       unite       |
# |   rockefeller    |     rockefel    |    rockefeller    |
# |    institute     |     institut    |     institute     |
# |    university    |     univers     |     university    |
# |     medical      |      medic      |      medical      |
# |    university    |     univers     |     university    |
# |      palade      |      palad      |       palade      |
# |     medicine     |     medicin     |      medicine     |
# |    residence     |      resid      |     residence     |
# |    department    |      depart     |     department    |
# |     medicine     |     medicin     |      medicine     |
# |    scientific    |     scientif    |     scientific    |
# |     affairs      |      affair     |      affairs      |
# |     medicine     |     medicin     |      medicine     |
# |    university    |     univers     |     university    |
# |     together     |      togeth     |      together     |
# |    physiology    |    physiolog    |     physiology    |
# |     medicine     |     medicin     |      medicine     |
# |   discoveries    |    discoveri    |    discoveries    |
# |    functional    |     function    |     functional    |
# |   organization   |      organ      |    organization   |
# |     seminal      |      semin      |      seminal      |
# |      events      |      event      |       events      |
# |   development    |     develop     |    development    |
# |     biology      |      biolog     |      biology      |
# |     related      |      relat      |       relate      |
# |     carried      |      carri      |       carry       |
# |   rockefeller    |     rockefel    |    rockefeller    |
# |    institute     |     institut    |     institute     |
# |     medical      |      medic      |      medical      |
# |     lecture      |      lectur     |      lecture      |
# |    delivered     |      deliv      |      deliver      |
# |     december     |      decemb     |      december     |
# |     entitled     |      entitl     |      entitle      |
# |     aspects      |      aspect     |      aspects      |
# |    secretion     |      secret     |     secretion     |
# |    foundation    |     foundat     |     foundation    |
# |     honorary     |     honorari    |      honorary     |
# |     academy      |     academi     |      academy      |
# |      palade      |      palad      |       palade      |
# |      became      |      becam      |       become      |
# |     cultural     |      cultur     |      cultural     |
# |     honorary     |     honorari    |      honorary     |
# |     academy      |     academi     |      academy      |
# |       arts       |       art       |        arts       |
# |     sciences     |      scienc     |      sciences     |
# |      palade      |      palad      |       palade      |
# |    department    |      depart     |     department    |
# |     biology      |      biolog     |      biology      |
# |    university    |     univers     |     university    |
# |    presently     |     present     |     presently     |
# |     biology      |      biolog     |      biology      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |   rockefeller    |     rockefel    |    rockefeller    |
# |    institute     |     institut    |     institute     |
# |     medical      |      medic      |      medical      |
# |      palade      |      palad      |       palade      |
# |    microscopy    |    microscopi   |     microscopy    |
# |      study       |      studi      |       study       |
# |     internal     |      intern     |      internal     |
# |   organization   |      organ      |    organization   |
# |    structures    |     structur    |     structure     |
# |    ribosomes     |     ribosom     |     ribosomes     |
# |   chloroplasts   |   chloroplast   |    chloroplasts   |
# |      others      |      other      |       others      |
# |    important     |      import     |     important     |
# |    discovery     |    discoveri    |     discovery     |
# |       made       |       made      |        make       |
# |   experimental   |    experiment   |    experimental   |
# |     strategy     |     strategi    |      strategy     |
# |      known       |      known      |        know       |
# |     analysis     |     analysi     |      analysis     |
# |    experiment    |      experi     |     experiment    |
# |      palade      |      palad      |       palade      |
# |    colleagues    |     colleagu    |     colleagues    |
# |       able       |       abl       |        able       |
# |    hypothesis    |    hypothesi    |     hypothesis    |
# |    secretory     |    secretori    |     secretory     |
# |     together     |      togeth     |      together     |
# |      bodies      |       bodi      |        body       |
# |     storage      |      storag     |      storage      |
# |    organelle     |     organell    |     organelle     |
# |      unique      |      uniqu      |       unique      |
# |     proteins     |     protein     |      proteins     |
# |    described     |     describ     |      describe     |
# |     together     |      togeth     |      together     |
# |      palade      |      palad      |       palade      |
# |    coworkers     |      cowork     |     coworkers     |
# |     concise      |      concis     |      concise      |
# |      palade      |      palad      |       palade      |
# |  autobiography   |  autobiographi  |   autobiography   |
# |    continued     |     continu     |      continue     |
# |    secretory     |    secretori    |     secretory     |
# |    succession    |     success     |     succession    |
# |    different     |      differ     |     different     |
# |      relied      |       reli      |        rely       |
# |   exclusively    |      exclus     |    exclusively    |
# |  fractionation   |     fraction    |   fractionation   |
# |  collaboration   |     collabor    |   collaboration   |
# |      lewis       |       lewi      |       lewis       |
# |      greene      |      green      |       greene      |
# |       led        |       led       |        lead       |
# | characterization |    character    |  characterization |
# |     granules     |      granul     |      granules     |
# |    discovery     |    discoveri    |     discovery     |
# |   segregation    |      segreg     |    segregation    |
# |    secretory     |    secretori    |     secretory     |
# |     products     |     product     |      products     |
# |    cisternal     |     cistern     |     cisternal     |
# |   endoplasmic    |    endoplasm    |    endoplasmic    |
# |      relied      |       reli      |        rely       |
# |    primarily     |    primarili    |     primarily     |
# | radioautography  | radioautographi |  radioautography  |
# |     involved     |      involv     |      involve      |
# |   experiments    |      experi     |     experiment    |
# |     animals      |       anim      |      animals      |
# |    pancreatic    |     pancreat    |     pancreatic    |
# |     carried      |      carri      |       carry       |
# |  collaboration   |     collabor    |   collaboration   |
# |    especially    |      especi     |     especially    |
# |      james       |       jame      |        jam        |
# |      series      |       seri      |       series      |
# |  investigations  |     investig    |   investigations  |
# |     produced     |      produc     |      produce      |
# |      ideas       |       idea      |       ideas       |
# |    synthesis     |     synthesi    |     synthesis     |
# |     proteins     |     protein     |      proteins     |
# |     critical     |      critic     |      critical     |
# |     lecture      |      lectur     |      lecture      |
# |    chemistry     |    chemistri    |     chemistry     |
# |      thomas      |      thoma      |       thomas      |
# |     studies      |      studi      |       study       |
# |    structure     |     structur    |     structure     |
# |     ribosome     |     ribosom     |      ribosome     |
# |    discovered    |      discov     |      discover     |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     personal     |      person     |      personal     |
# |      palade      |      palad      |       palade      |
# |     survived     |      surviv     |      survive      |
# |    university    |     univers     |     university    |
# |     marriage     |     marriag     |      marriage     |
# |    references    |      refer      |     reference     |
# |   bibliography   |   bibliographi  |    bibliography   |
# |     manfred      |      manfr      |      manfred      |
# |      legacy      |      legaci     |       legacy      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |  pancreatology   |   pancreatolog  |   pancreatology   |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |      years       |       year      |       years       |
# |     november     |      novemb     |      november     |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |   charismatic    |    charismat    |    charismatic    |
# |     biology      |      biolog     |      biology      |
# |      nature      |      natur      |       nature      |
# |     biology      |      biolog     |      biology      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |      wayne       |       wayn      |       wayne       |
# |   development    |     develop     |    development    |
# |     anatomy      |     anatomi     |      anatomy      |
# |    histology     |     histolog    |     histology     |
# |   contemporary   |   contemporari  |    contemporary   |
# |     biology      |      biolog     |      biology      |
# |     anatomy      |     anatomi     |      anatomy      |
# |    embryology    |    embryolog    |     embryology    |
# |      palade      |      palad      |       palade      |
# |     december     |      decemb     |      december     |
# |   permeability   |     permeabl    |    permeability   |
# |    capillary     |    capillari    |     capillary     |
# |     society      |     societi     |      society      |
# |    nephrology    |    nephrolog    |     nephrology    |
# |     october      |      octob      |      october      |
# |    chronicles    |     chronicl    |     chronicle     |
# |      claude      |      claud      |       claude      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     october      |      octob      |      october      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |    secretory     |    secretori    |     secretory     |
# |     biology      |      biolog     |      biology      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |      wayne       |       wayn      |       wayne       |
# |   development    |     develop     |    development    |
# |     anatomy      |     anatomi     |      anatomy      |
# |    histology     |     histolog    |     histology     |
# |   contemporary   |   contemporari  |    contemporary   |
# |     biology      |      biolog     |      biology      |
# |     anatomy      |     anatomi     |      anatomy      |
# |    embryology    |    embryolog    |     embryology    |
# |       july       |       juli      |        july       |
# |     informal     |      inform     |      informal     |
# |     tribute      |      tribut     |      tribute      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     biology      |      biolog     |      biology      |
# |     january      |     januari     |      january      |
# |  accomplishment  |    accomplish   |   accomplishment  |
# |      calude      |      calud      |       calude      |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     biology      |      biolog     |      biology      |
# |     ritchie      |      ritchi     |      ritchie      |
# |      cahill      |      cahil      |       cahill      |
# |     january      |     januari     |      january      |
# |     medical      |      medic      |      medical      |
# |    literature    |    literatur    |     literature    |
# |     medical      |      medic      |      medical      |
# |   association    |      associ     |    association    |
# |      george      |      georg      |       george      |
# |      palade      |      palad      |       palade      |
# |     triangle     |     triangl     |      triangle     |
# +------------------+-----------------+-------------------+

# %% [markdown]
# #9
# Change all the numbers from l_words into words, using num2words. Print the number of changes, and also the portion of list that contains first N changes (for example N=10).

# %%
! pip install num2words
# Out:
# Collecting num2words
#   Downloading https://files.pythonhosted.org/packages/eb/a2/ea800689730732e27711c41beed4b2a129b34974435bdc450377ec407738/num2words-0.5.10-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 13.2MB/s
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.6/dist-packages (from num2words) (0.6.2)
# Installing collected packages: num2words
# Successfully installed num2words-0.5.10

# %%
from num2words import num2words

N = 10
count = 0;

for i, x in enumerate(lws):
    if (x.isdigit()):
        lws[i] = num2words(x)
        count += 1
        if count == N:
            print(lws[:i])

print('Number of changes = ' + str(count))
# Out:
# ['george', 'emil', 'palade', 'formemrs', 'honfrms', 'romanian', 'pronunciation', 'eˈmil', 'paˈlade', 'listen', 'november', 'nineteen', 'one thousand, nine hundred and twelve', 'october', 'seven', 'two thousand and eight', 'cell', 'biologist', 'described', 'influential', 'cell', 'biologist', 'ever', 'one thousand, nine hundred and seventy-four', 'awarded', 'nobel', 'prize', 'physiology', 'medicine', 'along', 'albert', 'claude', 'christian', 'de', 'duve', 'prize', 'granted', 'innovations', 'electron', 'microscopy', 'cell', 'fractionation', 'together', 'laid', 'foundations', 'modern', 'molecular', 'cell', 'biology', 'notable', 'discovery', 'ribosomes', 'endoplasmic', 'reticulum', 'first', 'described', 'also', 'received', 'national', 'medal', 'science', 'biological', 'sciences', 'pioneering', 'discoveries', 'host', 'fundamental', 'highly', 'organized', 'structures', 'living', 'cells', 'one thousand, nine hundred and eighty-six', 'previously', 'elected', 'member', 'us', 'national', 'academy', 'science', 'one thousand, nine hundred and sixty-one', 'one thousand, nine hundred and sixty-eight', 'elected', 'honorary', 'fellow', 'royal', 'microscopical', 'society', 'honfrms', 'one thousand, nine hundred and eighty-four', 'elected', 'foreign', 'member', 'royal', 'society', 'formemrs', 'education', 'early', 'life', 'george', 'emil', 'palade', 'born', 'november']
# Number of changes = 78

# %% [markdown]
# #10
# Create a function that receives a string W as parameter. The function must return a list with all the sentences containing any inflexion of the word W. For example for W=running, these sentences could be in the list: "I like to run", "He runs the fastest". You need to apply stemming both on the word W but also on each word of the sentence.

# %%
def make_dict(data = data):
    sent = sent_tokenize(data)
    ps=nltk.PorterStemmer()
    dict_ = {}
    for sentence in sent:
        dict_[sentence] = [ps.stem(x.lower()) for x in word_tokenize(sentence) if x.isalnum()]
    return dict_


def get_all_sentences_with_inflections(W, data = data):
    ps=nltk.PorterStemmer()

    w = ps.stem(W.lower())

    dict_ = make_dict(data)

    list_ = []

    for key, value in dict_.items():
        if w in value:
            list_.append(key)

    return list_

res = get_all_sentences_with_inflections('Nobel')

print(res)
# Out:
# ['Described as "the most influential cell biologist ever", in 1974 he was awarded the Nobel Prize in Physiology and Medicine along with Albert Claude and Christian de Duve.', 'At UCSD, Palade was Professor of Medicine in Residence (Emeritus) in the Department of Cellular & Molecular Medicine, as well as a Dean for Scientific Affairs (Emeritus), in the School of Medicine at La Jolla, California.In 1970, he was awarded the Louisa Gross Horwitz Prize from Columbia University together with Renato Dulbecco winner of 1975 Nobel Prize in Physiology or Medicine "for discoveries concerning the functional organization of the cell that were seminal events in the development of modern cell biology", related to his previous research carried out at the Rockefeller Institute for Medical Research.', 'His Nobel lecture, delivered on December 12, 1974, was entitled:  "Intracellular Aspects of the Process of Protein Secretion", published in 1992 by the Nobel Prize Foundation, He was elected an Honorary member of the Romanian Academy in 1975.', "=== Palade's coworkers and approach in the 1960s ===\nThe following is a concise excerpt from Palade's Autobiography appearing in the Nobel Award documents\nIn the 1960s, I continued the work on the secretory process using in parallel or in succession two different approaches.", 'A critical review of this line of research is presented in the Nobel Lecture.', 'One notes also that the Nobel Prize in Chemistry was awarded in 2009 to Drs.', '"The Nobel chronicles.']
